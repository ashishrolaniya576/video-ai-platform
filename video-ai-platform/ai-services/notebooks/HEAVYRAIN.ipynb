# %%
# !git clone https://github.com/liruoteng/HeavyRainRemoval.git
# %cd HeavyRainRemoval
# !pip install tqdm scikit-image opencv-python numpy guided-filter-pytorch tensorboard_logger
# Out:
# Cloning into 'HeavyRainRemoval'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 75 (delta 2), reused 0 (delta 0), pack-reused 67 (from 1)
# Receiving objects: 100% (75/75), 13.21 MiB | 15.33 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# /content/HeavyRainRemoval
# ...

# %%
import urllib.request, os
urllib.request.urlretrieve(
    "https://www.dropbox.com/s/h8x6xl6epc45ngn/HeavyRain-stage2-2019-05-11-76_ckpt.pth.tar?dl=1",
    "HeavyRain-stage2-2019-05-11-76_ckpt.pth.tar"
)
os.makedirs(".ckpt", exist_ok=True)
import shutil
shutil.copy("HeavyRain-stage2-2019-05-11-76_ckpt.pth.tar", ".ckpt/HeavyRain-stage2-2019-05-11-76_ckpt.pth.tar")
print("Done!")
# Out:
# Done!

# %%
# Fix 1: helper.py - print statement + imresize
with open("helper.py", "r") as f:
    content = f.read()
content = content.replace(
    'print "random low value leq high value"',
    'print("random low value leq high value")'
)
content = content.replace("from scipy.misc import imresize\n", "")
content = content.replace(
    "img_data = imresize(img_data, [h,w])",
    "img_data = np.array(Image.fromarray(img_data.astype(np.uint8)).resize((w, h)))"
)
with open("helper.py", "w") as f:
    f.write(content)

# Fix 2: test.py - remove tensorboard import + fix integer divisions
with open("test.py", "r") as f:
    content = f.read()
content = content.replace("from tensorboard_logger import log_value\n", "")
content = content.replace("h = h / 2", "h = int(h / 2)")
content = content.replace("w = w / 2", "w = int(w / 2)")
content = content.replace("new_h = floor_h * 64", "new_h = int(floor_h * 64)")
content = content.replace("new_w = floor_w * 64", "new_w = int(floor_w * 64)")
with open("test.py", "w") as f:
    f.write(content)

# Fix 3: Base.py - fix torch.load for old checkpoint format
with open("Base.py", "r") as f:
    content = f.read()
content = content.replace(
    "ckpt = torch.load(ckpt_path)",
    "ckpt = torch.load(ckpt_path, weights_only=False, encoding='latin1')"
)
with open("Base.py", "w") as f:
    f.write(content)

# Fix 4: model.py - fix integer divisions for channel counts
import re
with open("model.py", "r") as f:
    content = f.read()
lines = content.split("\n")
fixed_lines = []
for line in lines:
    if re.search(r'\w\s*/\s*\d', line) and '//' not in line and '#' not in line.split('/')[0]:
        new_line = re.sub(r'(?<!/)/(?!/)', '//', line)
        fixed_lines.append(new_line)
    else:
        fixed_lines.append(line)
content = "\n".join(fixed_lines)
with open("model.py", "w") as f:
    f.write(content)

print("All fixes applied!")
# Out:
# All fixes applied!

# %%
import os, shutil
from google.colab import files

os.makedirs("data/web", exist_ok=True)

uploaded = files.upload()

for fname in uploaded.keys():
    shutil.move(fname, f"data/web/{fname}")

print("Uploaded:", os.listdir("data/web"))
# Out:
#      <input type="file" id="files-c1a99721-8a61-4511-ad56-f46741076660" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1a99721-8a61-4511-ad56-f46741076660">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python test.py
# Out:
# 2026-06-21 17:39:58.073225: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
for fname in os.listdir("out/test/single"):
    files.download(f"out/test/single/{fname}")

# %%
import os, shutil
from google.colab import files

os.makedirs("data/web", exist_ok=True)

uploaded = files.upload()

for fname in uploaded.keys():
    shutil.move(fname, f"data/web/{fname}")

print("Uploaded:", os.listdir("data/web"))
# Out:
#      <input type="file" id="files-939a6020-26e1-48cb-97f3-759377ef9026" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-939a6020-26e1-48cb-97f3-759377ef9026">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python test.py
# Out:
# 2026-06-20 04:56:34.362923: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
for fname in os.listdir("out/test/single"):
    files.download(f"out/test/single/{fname}")

# %%
import os, shutil
from google.colab import files

# Clear ALL old files first
shutil.rmtree("data/web")
os.makedirs("data/web", exist_ok=True)
shutil.rmtree("out", ignore_errors=True)

print("Folder cleared:", os.listdir("data/web"))

uploaded = files.upload()
for fname in uploaded.keys():
    shutil.move(fname, f"data/web/{fname}")

print("Only your image is now in folder:", os.listdir("data/web"))
# Out:
# Folder cleared: []
#      <input type="file" id="files-85af42f0-5c64-4709-b718-f0a95410e50b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85af42f0-5c64-4709-b718-f0a95410e50b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !python test.py
# Out:
# 2026-06-20 04:59:21.366385: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
for fname in os.listdir("out/test/single"):
    files.download(f"out/test/single/{fname}")

# %%
import os, shutil
from google.colab import files

# Clear ALL old files first
shutil.rmtree("data/web")
os.makedirs("data/web", exist_ok=True)
shutil.rmtree("out", ignore_errors=True)

print("Folder cleared:", os.listdir("data/web"))

uploaded = files.upload()
for fname in uploaded.keys():
    shutil.move(fname, f"data/web/{fname}")

print("Only your image is now in folder:", os.listdir("data/web"))
# Out:
# Folder cleared: []
#      <input type="file" id="files-641bb3b4-b04f-4b97-9606-ef55975a590e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-641bb3b4-b04f-4b97-9606-ef55975a590e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !python test.py
# Out:
# 2026-06-20 05:01:21.666255: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
for fname in os.listdir("out/test/single"):
    files.download(f"out/test/single/{fname}")

# %%
import os, shutil
from google.colab import files

# Clear ALL old files first
shutil.rmtree("data/web")
os.makedirs("data/web", exist_ok=True)
shutil.rmtree("out", ignore_errors=True)

print("Folder cleared:", os.listdir("data/web"))

uploaded = files.upload()
for fname in uploaded.keys():
    shutil.move(fname, f"data/web/{fname}")

print("Only your image is now in folder:", os.listdir("data/web"))
# Out:
# Folder cleared: []
#      <input type="file" id="files-65742d73-4877-4966-8903-91f608d3548d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65742d73-4877-4966-8903-91f608d3548d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !python test.py
# Out:
# 2026-06-20 05:03:51.541372: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
for fname in os.listdir("out/test/single"):
    files.download(f"out/test/single/{fname}")

# %%
import os, shutil
from google.colab import files

# Clear ALL old files first
shutil.rmtree("data/web")
os.makedirs("data/web", exist_ok=True)
shutil.rmtree("out", ignore_errors=True)

print("Folder cleared:", os.listdir("data/web"))

uploaded = files.upload()
for fname in uploaded.keys():
    shutil.move(fname, f"data/web/{fname}")

print("Only your image is now in folder:", os.listdir("data/web"))
# Out:
# Folder cleared: []
#      <input type="file" id="files-7f5a1263-b2c1-413b-bf50-4dea303e6c65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f5a1263-b2c1-413b-bf50-4dea303e6c65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !python test.py
# Out:
# 2026-06-20 05:27:04.534584: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
for fname in os.listdir("out/test/single"):
    files.download(f"out/test/single/{fname}")

# %%
import os, shutil
from google.colab import files
from PIL import Image

# Clear folder
shutil.rmtree("data/web")
os.makedirs("data/web", exist_ok=True)
shutil.rmtree("out", ignore_errors=True)

uploaded = files.upload()
for fname in uploaded.keys():
    # Convert to RGB (removes alpha channel)
    img = Image.open(fname).convert('RGB')
    # Save as jpg to ensure 3 channels
    out_name = fname.rsplit('.', 1)[0] + '.jpg'
    img.save(f"data/web/{out_name}")
    print(f"Saved as RGB: {out_name}")

print("Folder:", os.listdir("data/web"))
# Out:
#      <input type="file" id="files-e1a1ab49-0d38-46b0-8f51-917753f67b65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1a1ab49-0d38-46b0-8f51-917753f67b65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python test.py
# Out:
# 2026-06-21 17:41:14.680309: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
for fname in os.listdir("out/test/single"):
    files.download(f"out/test/single/{fname}")

# %%
import os, shutil
from google.colab import files

# Clear ALL old files first
shutil.rmtree("data/web")
os.makedirs("data/web", exist_ok=True)
shutil.rmtree("out", ignore_errors=True)

print("Folder cleared:", os.listdir("data/web"))

uploaded = files.upload()
for fname in uploaded.keys():
    shutil.move(fname, f"data/web/{fname}")

print("Only your image is now in folder:", os.listdir("data/web"))
# Out:
# Folder cleared: []
#      <input type="file" id="files-fd70cac1-8722-4c60-8aaf-ee2b9bc37c4c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd70cac1-8722-4c60-8aaf-ee2b9bc37c4c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !python test.py
# Out:
# 2026-06-20 09:23:10.090731: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
for fname in os.listdir("out/test/single"):
    files.download(f"out/test/single/{fname}")
